# %% [markdown]
# 1) Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.

# %%
num1 = int(input("Digite um numero: "))
num2 = int(input("Digite um numero: "))

print(max(num1,num2))
# Out:
# Digite um numero: 37
# Digite um numero: 3
# 37

# %% [markdown]
# 2) Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

# %%
entrada = input("Digite o percentual de crescimento de produção: ")
percentual = float(entrada)

if percentual > 0:
    print("Resultado: Houve um crescimento de", percentual, "%.")
elif percentual < 0:
    print("Resultado: Houve um decrescimento de", percentual, "%.")
else:
    print("Resultado: A produção permaneceu estável (0%).")

# %% [markdown]
# 3) Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.

# %%
letra = input("Digite uma letra: ").lower()

if ( letra in "aeiou"):
  print("Essa letra é uma vogal")
else:
  print("Essa letra é uma consoante")
# Out:
# Digite uma letra: a
# Essa letra é uma vogal

# %% [markdown]
# 4) Escreva um programa que leia valores médios de preços de um modelo de carro por 3 anos consecutivos e exiba o valor mais alto e mais baixo entre esses três anos.

# %%
preco1= float(input("Digite o preço do primeiro carro: "))
preco2 =float(input("Digite o preço do segundo carro: "))
preco3=float(input("Digite o preço do terceiro carro: "))

valores = [preco1,preco2,preco3]

print("O maior numero é", max(valores))
print("O menor numero é", min(valores))
# Out:
# Digite o preço do primeiro carro: 4550.98
# Digite o preço do segundo carro: 9000
# Digite o preço do terceiro carro: 7554
# O maior numero é 9000.0
# O menor numero é 4550.98

# %% [markdown]
# 5) Escreva um programa que pergunte sobre o preço de três produtos e indique qual é o produto mais barato para comprar.

# %%
val1 = float(input("Digite o preço do primeiro produto: "))
val2 = float(input("Digite o preço do segundo produto: "))
val3 = float(input("Digite o preço do terceiro produto: "))

lista = [val1,val2,val3]
if(val1 == val2 == val3):
  print("Todos os valores são iguais")
else:
  print("O maior valor é: ", max(lista))
  print("o menor valor é:", min(lista))
# Out:
# Digite o preço do primeiro produto: 10
# Digite o preço do segundo produto: 20
# Digite o preço do terceiro produto: 30
# O maior valor é:  30.0
# o menor valor é: 10.0

# %% [markdown]
# 6) Escreva um programa que leia três números e os exiba em ordem decrescente.

# %%
numeros = [8,11,3]
numeros.sort(reverse = True)
print(numeros)

# o sort é para organizar a lista em ordem crescente o o reverse ele vai virar a lista ao contrario ou seja vai ficar decrecente
# Out:
# [11, 8, 3]

# %% [markdown]
# 7) Escreva um programa que pergunte em qual turno a pessoa usuária estuda ("manhã", "tarde" ou "noite") e exiba a mensagem "Bom Dia!", "Boa Tarde!", "Boa Noite!", ou "Valor Inválido!", conforme o caso.

# %%
turno = input("Digite o seu turno(manha,tarde,noite): ").lower()

if(turno == "manha"):
  print("Bom dia!")
elif(turno == "tarde"):
  print("Boa tarde!")
elif(turno == "noite"):
  print("Boa noite")
else:
 print("valor invalido")
# Out:
# Digite o seu turno(manha,tarde,noite): touca
# valor invalido

# %% [markdown]
# 8) Escreva um programa que peça um número inteiro à pessoa usuária e determine se ele é par ou ímpar. Dica: Você pode utilizar o operador módulo %.

# %%
num = int(input("Digite um numero inteiro: "))
if (num % 2 == 0):
  print("O numero é par")
else:
  print("O numero é impar")
# Out:
# Digite um numero inteiro: 78
# O numero é par

# %% [markdown]
# 9) Escreva um programa que peça um número à pessoa usuária e informe se ele é inteiro ou decimal.

# %%
numero = float(input("Digite um número: "))
if (numero % 1 == 0):
  print("Esse numero é inteiro")
else:
  print("Esse numero é decimal")

# %% [markdown]
# 10) Um programa deve ser escrito para ler dois números e, em seguida, perguntar à pessoa usuária qual operação ele deseja realizar. O resultado da operação deve incluir informações sobre o número - se é par ou ímpar, positivo ou negativo e inteiro ou decimal.

# %%
num1 = float(input("Digite o primeiro numero: "))
num2 = float(input("Digite o segundo numero: "))
opera = int(input("Qual operador deseja usar : (1+) (2-) (3*) (4/)"))

soma = num1 + num2
sub = num1 - num2
mult = num1 * num2
div = num1 / num2

if(opera == 1):
  resultados = soma
  print(f"O resultado da soma é {soma}")
elif(opera == 2):
  resultados = sub
  print(f"O resultado da subtração é {sub} ")
elif(opera == 3):
  resultados = mult
  print(f"O resultado da multiplicação é {mult}")
elif(opera == 4):
  if(num2 != 0):
    resultados = div
    print(f"O resultado da divisão é {div }")
  else:
    print("Não é possivel dividir por 0")
else:
  print("voce digitou errado")
if(resultados >= 0 ):
  print("Seu numero é positivo ")
else:
  print("Seu numero é negativo")

if(resultados % 1 == 0):
  print("Seu numero é inteiro")
  if(resultados % 2 == 0):
    print("Seu numero é par")
  else:
    print("Seu numero é impar")
else:
  print("Seu numeor é decimal")
# Out:
# Digite o primeiro numero: 3
# Digite o segundo numero: 5
# Qual operador deseja usar : (1+) (2-) (3*) (4/)4
# O resultado da divisão é 0.6
# Seu numero é positivo
# Seu numeor é decimal

# %% [markdown]
# 11) Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
#
# Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
# Triângulo Equilátero: três lados iguais;
# Triângulo Isósceles: quaisquer dois lados iguais;
# Triângulo Escaleno: três lados diferentes.

# %%
lado1 = float(input("Digite o lado 1: "))
lado2 = float(input("Digite o lado 2: "))
lado3 = float(input("Digite o lado 3: "))

if (lado1 + lado2 > lado3 and lado2 + lado3 > lado1 and lado3 + lado1 > lado2):
  if(lado1 == lado2 == lado3):
    print("É um triangulo equilatero")
  elif(lado1 == lado2  or lado2 == lado3 or lado3 == lado1 ):
    print("É um triangulo isosceles")
  else:
    print("É um triangulo escaleno")
else:
  print("Isso não é um triangulo")
# Out:
# Digite o lado 1: 3
# Digite o lado 2: 5
# Digite o lado 3: 3
# É um triangulo escaleno

# %% [markdown]
# 12) Um estabelecimento está vendendo combustíveis com descontos variados. Para o etanol, se a quantidade comprada for até 15 litros, o desconto será de 2% por litro. Caso contrário, será de 4% por litro. Para o diesel, se a quantidade comprada for até 15 litros, o desconto será de 3% por litro. Caso contrário, será de 5% por litro. O preço do litro de diesel é R$ 2,00 e o preço do litro de etanol é R$ 1,70. Escreva um programa que leia a quantidade de litros vendidos e o tipo de combustível (E para etanol e D para diesel) e calcule o valor a ser pago pelo cliente. Tenha em mente algumas dicas:
#
# O do valor do desconto será a multiplicação entre preço do litro, quantidade de litros e o valor do desconto.
# O valor a ser pago por um cliente será o resultado da multiplicação do preço do litro pela quantidade de litros menos o valor de desconto resultante do cálculo.

# %%
etanol = float(input("Digite a quantidade de litros de etanol: "))
diesel = float(input("Digite a quantidade de litros de diesel: "))

pre_etanol = 2.0
pre_diesel = 1.70

# Cálculo etanol
if etanol <= 15:
    total_etanol = etanol * pre_etanol * 0.98  # 2% desconto
else:
    total_etanol = etanol * pre_etanol * 0.96  # 4% desconto

# Cálculo diesel
if diesel <= 15:
    total_diesel = diesel * pre_diesel * 0.97  # 3% desconto
else:
    total_diesel = diesel * pre_diesel * 0.95  # 5% desconto

total = total_etanol + total_diesel

print(f"Total a pagar: R$ {total:.2f}")
