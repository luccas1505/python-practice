# %% [markdown]
# 1) Escreva um programa que peça dois números inteiros e imprima todos os números inteiros entre eles.

# %%
num1 = int(input("Digite o 1 numero: "))
num2 = int (input("Digite o 2 numero: "))

if(num1 < num2):
  for contador in range(num1+1,num2):
    print(contador)

else:
  for contador in range(num2+1,num1):
    print(contador)
# Out:
# Digite o 1 numero: 7
# Digite o 2 numero: 2
# 3
# 4
# 5
# 6

# %% [markdown]
# 2) Escreva um programa para calcular quantos dias levará para a colônia de uma bactéria A ultrapassar ou igualar a colônia de uma bactéria B, com base nas taxas de crescimento de 3% e 1,5% respectivamente. Considere que a colônia A inicia com 4 elementos e a B com 10.

# %%
coloniaA = 4
taxaCrescimentoA =0.03

coloniaB = 10
taxaCrescimentoB =0.015

dias =0

while(coloniaA < coloniaB):
  coloniaA += (coloniaA * taxaCrescimentoA)
  coloniaB += (coloniaB * taxaCrescimentoB)
  dias+=1
  print(f"A colonia A esta com: {coloniaA} elementos")
  print(f"A colonia B esta com: {coloniaB} elementos")
  print(f"Total de dias:{dias}")
# Out:
# A colonia A esta com: 4.12 elementos
# A colonia B esta com: 10.15 elementos
# Total de dias:1
# A colonia A esta com: 4.2436 elementos
# A colonia B esta com: 10.30225 elementos
# Total de dias:2
# A colonia A esta com: 4.370908 elementos
# A colonia B esta com: 10.456783750000001 elementos
# Total de dias:3
# A colonia A esta com: 4.50203524 elementos
# A colonia B esta com: 10.61363550625 elementos
# Total de dias:4
# A colonia A esta com: 4.637096297199999 elementos
# A colonia B esta com: 10.77284003884375 elementos
# Total de dias:5
# A colonia A esta com: 4.776209186116 elementos
# A colonia B esta com: 10.934432639426406 elementos
# Total de dias:6
# A colonia A esta com: 4.91949546169948 elementos
# A colonia B esta com: 11.098449129017803 elementos
# Total de dias:7
# A colonia A esta com: 5.067080325550465 elementos
# A colonia B esta com: 11.26492586595307 elementos
# Total de dias:8
# A colonia A esta com: 5.219092735316979 elementos
# A colonia B esta com: 11.433899753942367 elementos
# Total de dias:9
# A colonia A esta com: 5.375665517376488 elementos
# A colonia B esta com: 11.605408250251502 elementos
# Total de dias:10
# A colonia A esta com: 5.536935482897783 elementos
# A colonia B esta com: 11.779489374005275 elementos
# Total de dias:11
# A colonia A esta com: 5.703043547384716 elementos
# A colonia B esta com: 11.956181714615354 elementos
# Total de dias:12
# A colonia A esta com: 5.874134853806257 elementos
# A colonia B esta com: 12.135524440334585 elementos
# Total de dias:13
# A colonia A esta com: 6.050358899420445 elementos
# A colonia B esta com: 12.317557306939603 elementos
# Total de dias:14
# A colonia A esta com: 6.231869666403059 elementos
# A colonia B esta com: 12.502320666543698 elementos
# Total de dias:15
# A colonia A esta com: 6.41882575639515 elementos
# A colonia B esta com: 12.689855476541853 elementos
# Total de dias:16
# A colonia A esta com: 6.6113905290870045 elementos
# A colonia B esta com: 12.88020330868998 elementos
# Total de dias:17
# A colonia A esta com: 6.809732244959615 elementos
# A colonia B esta com: 13.07340635832033 elementos
# Total de dias:18
# A colonia A esta com: 7.014024212308403 elementos
# A colonia B esta com: 13.269507453695136 elementos
# Total de dias:19
# A colonia A esta com: 7.224444938677655 elementos
# A colonia B esta com: 13.468550065500562 elementos
# Total de dias:20
# A colonia A esta com: 7.441178286837984 elementos
# A colonia B esta com: 13.67057831648307 elementos
# Total de dias:21
# A colonia A esta com: 7.664413635443124 elementos
# A colonia B esta com: 13.875636991230316 elementos
# Total de dias:22
# A colonia A esta com: 7.894346044506417 elementos
# A colonia B esta com: 14.08377154609877 elementos
# Total de dias:23
# A colonia A esta com: 8.131176425841609 elementos
# A colonia B esta com: 14.295028119290253 elementos
# Total de dias:24
# A colonia A esta com: 8.375111718616857 elementos
# A colonia B esta com: 14.509453541079607 elementos
# Total de dias:25
# A colonia A esta com: 8.626365070175362 elementos
# A colonia B esta com: 14.727095344195801 elementos
# Total de dias:26
# A colonia A esta com: 8.885156022280624 elementos
# A colonia B esta com: 14.948001774358739 elementos
# Total de dias:27
# A colonia A esta com: 9.151710702949043 elementos
# A colonia B esta com: 15.17222180097412 elementos
# Total de dias:28
# A colonia A esta com: 9.426262024037515 elementos
# A colonia B esta com: 15.399805127988731 elementos
# Total de dias:29
# A colonia A esta com: 9.70904988475864 elementos
# A colonia B esta com: 15.630802204908562 elementos
# Total de dias:30
# A colonia A esta com: 10.000321381301399 elementos
# A colonia B esta com: 15.86526423798219 elementos
# Total de dias:31
# A colonia A esta com: 10.30033102274044 elementos
# A colonia B esta com: 16.103243201551923 elementos
# Total de dias:32
# A colonia A esta com: 10.609340953422654 elementos
# A colonia B esta com: 16.344791849575202 elementos
# Total de dias:33
# A colonia A esta com: 10.927621182025334 elementos
# A colonia B esta com: 16.589963727318832 elementos
# Total de dias:34
# A colonia A esta com: 11.255449817486094 elementos
# A colonia B esta com: 16.838813183228613 elementos
# Total de dias:35
# A colonia A esta com: 11.593113312010676 elementos
# A colonia B esta com: 17.09139538097704 elementos
# Total de dias:36
# A colonia A esta com: 11.940906711370996 elementos
# A colonia B esta com: 17.347766311691696 elementos
# Total de dias:37
# A colonia A esta com: 12.299133912712126 elementos
# A colonia B esta com: 17.607982806367072 elementos
# Total de dias:38
# A colonia A esta com: 12.66810793009349 elementos
# A colonia B esta com: 17.87210254846258 elementos
# Total de dias:39
# A colonia A esta com: 13.048151167996293 elementos
# A colonia B esta com: 18.140184086689516 elementos
# Total de dias:40
# A colonia A esta com: 13.439595703036183 elementos
# A colonia B esta com: 18.412286847989858 elementos
# Total de dias:41
# A colonia A esta com: 13.842783574127267 elementos
# A colonia B esta com: 18.688471150709706 elementos
# Total de dias:42
# A colonia A esta com: 14.258067081351085 elementos
# A colonia B esta com: 18.968798217970352 elementos
# Total de dias:43
# A colonia A esta com: 14.685809093791617 elementos
# A colonia B esta com: 19.253330191239908 elementos
# Total de dias:44
# A colonia A esta com: 15.126383366605365 elementos
# A colonia B esta com: 19.542130144108505 elementos
# Total de dias:45
# A colonia A esta com: 15.580174867603526 elementos
# A colonia B esta com: 19.83526209627013 elementos
# Total de dias:46
# A colonia A esta com: 16.047580113631632 elementos
# A colonia B esta com: 20.132791027714184 elementos
# Total de dias:47
# A colonia A esta com: 16.529007517040583 elementos
# A colonia B esta com: 20.434782893129896 elementos
# Total de dias:48
# A colonia A esta com: 17.0248777425518 elementos
# A colonia B esta com: 20.741304636526845 elementos
# Total de dias:49
# A colonia A esta com: 17.535624074828355 elementos
# A colonia B esta com: 21.052424206074747 elementos
# Total de dias:50
# A colonia A esta com: 18.061692797073206 elementos
# A colonia B esta com: 21.368210569165868 elementos
# Total de dias:51
# A colonia A esta com: 18.603543580985402 elementos
# A colonia B esta com: 21.688733727703355 elementos
# Total de dias:52
# A colonia A esta com: 19.161649888414964 elementos
# A colonia B esta com: 22.014064733618905 elementos
# Total de dias:53
# A colonia A esta com: 19.73649938506741 elementos
# A colonia B esta com: 22.34427570462319 elementos
# Total de dias:54
# A colonia A esta com: 20.328594366619434 elementos
# A colonia B esta com: 22.679439840192536 elementos
# Total de dias:55
# A colonia A esta com: 20.938452197618016 elementos
# A colonia B esta com: 23.019631437795425 elementos
# Total de dias:56
# A colonia A esta com: 21.566605763546555 elementos
# A colonia B esta com: 23.364925909362356 elementos
# Total de dias:57
# A colonia A esta com: 22.21360393645295 elementos
# A colonia B esta com: 23.715399798002792 elementos
# Total de dias:58
# A colonia A esta com: 22.88001205454654 elementos
# A colonia B esta com: 24.071130794972834 elementos
# Total de dias:59
# A colonia A esta com: 23.566412416182935 elementos
# A colonia B esta com: 24.432197756897427 elementos
# Total de dias:60
# A colonia A esta com: 24.273404788668422 elementos
# A colonia B esta com: 24.79868072325089 elementos
# Total de dias:61
# A colonia A esta com: 25.001606932328475 elementos
# A colonia B esta com: 25.170660934099654 elementos
# Total de dias:62
# A colonia A esta com: 25.75165514029833 elementos
# A colonia B esta com: 25.54822084811115 elementos
# Total de dias:63

# %% [markdown]
# 3) Para tratar uma quantidade de 15 dados de avaliações de pessoas usuárias de um serviço da empresa, precisamos verificar se as notas são válidas. Então, escreva um programa que vai receber a nota de 0 a 5 de todos os dados e verificar se é um valor válido. Caso seja inserido uma nota acima de 5 ou abaixo de 0, repita até que a pessoa usuária insira um valor válido.

# %%
for i in range(15):
    while True:
        notas = float(input(f"Digite a nota {i+1} (0 a 5): "))

        if 0 <= notas <= 5:
            print(f"Nota {i+1}: {notas}")
            break
        else:
            print("Nota inválida, tente novamente")

# %% [markdown]
# 4) Desenvolva um programa que leia um conjunto indeterminado de temperaturas em Celsius e informe a média delas. A leitura deve ser encerrada ao ser enviado o valor -273°C.

# %%
contador = 0
temperaturaF = 0
while True:
  temperatura = float(input("Digite a temperatura em Celcius: "))
  if(temperatura != -273):
    contador +=1
    temperaturaF += temperatura
  else:
    media = temperaturaF / contador
    print(f"A média é {media}")
    print("O programa foi encerrado pois vc digitou o valor proibido")
    break
# Out:
# Digite a temperatura em Celcius: 5
# Digite a temperatura em Celcius: 10
# Digite a temperatura em Celcius: 55
# Digite a temperatura em Celcius: -273
# A média é 23.333333333333332
# O programa foi encerrado pois vc digitou o valor proibido

# %% [markdown]
# 5) Escreva um programa que calcule o fatorial de um número inteiro fornecido pela pessoa usuária. Lembrando que o fatorial de um número inteiro é a multiplicação desse número por todos os seus antecessores até o número 1. Por exemplo, o fatorial de 5 é 5 x 4 x 3 x 2 x 1 = 120.

# %%
numero = int(input("Digite um numero inteiro: "))
fatorial = 1
for i in range(1,numero + 1):
  fatorial *= i
print(f"O fatorial de {numero} é {fatorial}")
# Out:
# Digite um numero inteiro: 3
# O fatorial de 3 é 6

# %% [markdown]
# 6) Escreva um programa que gere a tabuada de um número inteiro de 1 a 10, de acordo com a escolha da pessoa usuária. Como exemplo, para o número 2, a tabuada deve ser mostrada no seguinte formato:

# %%
numero = int(input("Escolha um numero: "))
for i in range(1,11):
  print(f"{numero} x {i} = {numero * i}")

# %% [markdown]
# 7) Os números primos possuem várias aplicações dentro da Ciência de Dados em criptografia e segurança, por exemplo. Um número primo é aquele que é divisível apenas por um e por ele mesmo. Assim, faça um programa que peça um número inteiro e determine se ele é ou não um número primo.

# %%
numero = int(input("Digite um número : "))
primo = True
for i in range(2,numero):
 if(numero % i == 0 ):
  primo = False

if(primo == False):
    print(f"{numero} não é um numero primo ")
else:
   print(f"{numero} é um numero primo")
# Out:
# Digite um número : 89
# 89 é um numero primo

# %% [markdown]
# 8) Vamos entender a distribuição de idades de pensionistas de uma empresa de previdência. Escreva um programa que leia as idades de uma quantidade não informada de clientes e mostre a distribuição em intervalos de [0-25], [26-50], [51-75] e [76-100]. Encerre a entrada de dados com um número negativo.

# %%
contador1 = 0
contador2 = 0
contador3= 0
contador4 = 0
while True:
  idade = int(input("Digite a idade do pensionista: "))
  if(idade < 0):
    print(f"Existem {contador1} pessoas entre 0 e 25 anos")
    print(f"Existem {contador2} pessoas entre 26 e 50 anos")
    print(f"Existem {contador3} pessoas entre 51 e 75 anos")
    print(f"Existem {contador4} pessoas entre 76 e 100 anos")
    break
  elif(idade >= 0 and idade <= 25):
    contador1 +=1
  elif(idade >= 26 and idade <=50):
    contador2 +=1
  elif(idade >=51 and idade<=75):
    contador3 +=1
  elif(idade >=76 and idade <=100):
    contador4 +=1
  else:
    print("Vc digitou uma idade invalida")
# Out:
# Digite a idade do pensionista: 26
# Digite a idade do pensionista: 45
# Digite a idade do pensionista: 78
# Digite a idade do pensionista: 99
# Digite a idade do pensionista: 2
# Digite a idade do pensionista: 5
# Digite a idade do pensionista: 17
# Digite a idade do pensionista: 29
# Digite a idade do pensionista: 57
# Digite a idade do pensionista: 58
# Digite a idade do pensionista: 79
# Digite a idade do pensionista: 83
# Digite a idade do pensionista: 25
# Digite a idade do pensionista: 28
# Digite a idade do pensionista: -1
# Existem 4 pessoas entre 0 e 25 anos
# Existem 4 pessoas entre 26 e 50 anos
# Existem 2 pessoas entre 51 e 75 anos
# Existem 4 pessoas entre 76 e 100 anos

# %% [markdown]
# 9) Em uma eleição para gerência em uma empresa com 20 pessoas colaboradoras, existem quatro candidatos(as). Escreva um programa que calcule o(a) vencedor(a) da eleição. A votação ocorreu da seguinte maneira:
#
# Cada colaborador(a) votou em uma das quatro pessoas candidatas (que representamos pelos números 1, 2, 3 e 4).
# Também foram contabilizados os votos nulos (representados pelo número 5) e os votos em branco (representados pelo número 6).
# Ao final da votação, o programa deve exibir o número total de votos para cada candidato(a), os nulos e os votos em branco. Além disso, deve calcular e exibir a porcentagem de votos nulos em relação ao total de votos e a porcentagem de votos em branco em relação ao total de votos.

# %%
contador1 = 0
contador2 = 0
contador3 = 0
contador4 = 0
contador5 = 0
contador6 = 0

for i in range(1,21):
  while True: #aqui é so uma validação q fiz com o while pra caso a pessoa digite um numero diferente de 1 a 6, o voot n valide e faça a pessoa digitar novamente
    votos = int(input("Digite seu voto de 1 a 6: "))
    if(1 <=votos <= 6 ):
      break
    else:
      print("Voce digitou um valor invalido")
  if(votos == 1 ):
    contador1 +=1
  elif(votos == 2):
    contador2 +=1
  elif(votos == 3):
    contador3 +=1
  elif(votos == 4):
    contador4 +=1
  elif(votos == 5):
    contador5 +=1
  elif(votos == 6):
    contador6 +=1
porcentagemN = (contador5/20) * 100
porcentagemB = (contador6/20) * 100
print(f"A quantidade de votos foram:\n"
      f"candidato 1 teve {contador1} votos\n"
      f"candidato 2 teve {contador2} votos\n"
      f"candidato 3 teve {contador3} votos\n"
      f"candidato 4 teve {contador4} votos\n"
      f"candidato 5 teve {contador5} votos\n"
      f"candidato 6 teve {contador6} votos\n"
      f"A quantidade de votos nulos sobre o total foi de : {porcentagemN} %\n"
      f"A quantidade de votos brancos sobre o total foi de :{porcentagemB} %")
# Out:
# Digite seu voto de 1 a 6: 6
# Digite seu voto de 1 a 6: 2
# Digite seu voto de 1 a 6: 3
# Digite seu voto de 1 a 6: 6
# Digite seu voto de 1 a 6: 1
# Digite seu voto de 1 a 6: 1
# Digite seu voto de 1 a 6: 4
# Digite seu voto de 1 a 6: 6
# Digite seu voto de 1 a 6: 5
# Digite seu voto de 1 a 6: 5
# Digite seu voto de 1 a 6: 2
# Digite seu voto de 1 a 6: 2
# Digite seu voto de 1 a 6: 3
# Digite seu voto de 1 a 6: 4
# Digite seu voto de 1 a 6: 1
# Digite seu voto de 1 a 6: 6
# Digite seu voto de 1 a 6: 2
# Digite seu voto de 1 a 6: 4
# Digite seu voto de 1 a 6: 5
# Digite seu voto de 1 a 6: 2
# A quantidade de votos foram:
# candidato 1 teve 3 votos
# candidato 2 teve 5 votos
# candidato 3 teve 2 votos
# candidato 4 teve 3 votos
# candidato 5 teve 3 votos
# candidato 6 teve 4 votos
# A quantidade de votos nulos sobre o total foi de : 15.0 %A quantidade de votos brancos sobre o total foi de :20.0 %
