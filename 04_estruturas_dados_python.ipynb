# %% [markdown]
# 1) Faça um programa que tenha a seguinte lista contendo os valores de gastos de uma empresa de papel [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]. Com esses valores, faça um programa que calcule a média de gastos. Dica: use as funções built-in sum() e len().

# %%
lista = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]
soma = sum(lista)
total = len(lista)
media = (soma / total)
print(media)
# Out:
# 3144.222

# %% [markdown]
# 2) Com os mesmos dados da questão anterior, defina quantas compras foram realizadas acima de 3000 reais e calcule a porcentagem quanto ao total de compras.

# %%
contador2 = 0
contador = 0
lista = [2172.54, 3701.35, 3518.09, 3456.61, 3249.38, 2840.82, 3891.45, 3075.26, 2317.64, 3219.08]
for i in lista:
  if(i > 3000):
    contador+=1
  else:
    contador2+=1
total = contador2 + contador
porcentagem = ((contador / total) * 100)

print(f"A quantidade de compras realizadas acima de R$ 3000 foi: {contador}\n"
f"e a porcentagem de compras acima de  R$ 3000 sobre o total foi: {porcentagem}%")
# Out:
# A quantidade de compras realizadas acima de R$ 3000 foi: 7
# e a porcentagem de compras acima de  R$ 3000 sobre o total foi: 70.0%

# %% [markdown]
# 3) Faça um código que colete em uma lista 5 números inteiros quaisquer e imprima a lista. Exemplo: [1,4,7,2,4].

# %%
lista = []

for i in range(0,5):
  numero = int(input("Digite um numero"))
  lista.append(numero)
print(lista)
# Out:
# Digite um numero2
# Digite um numero4
# Digite um numero5
# Digite um numero6
# Digite um numero7
# [2, 4, 5, 6, 7]

# %% [markdown]
# 4) Colete novamente 5 inteiros e imprima a lista em ordem inversa à enviada.

# %%
lista = []

for i in range(0,5):
  numero = int(input("Digite um um número: "))
  lista.append(numero)
lista.reverse()
print(f"Essa é a lista: {lista}")
# Out:
# Digite um um número: 2
# Digite um um número: 5
# Digite um um número: 3
# Digite um um número: 10
# Digite um um número: 8
# Essa é a lista: [8, 10, 3, 5, 2]

# %% [markdown]
# 5) Faça um programa que, ao inserir um número qualquer, cria uma lista contendo todos os números primos entre 1 e o número digitado.

# %%
numero = int(input("Digite um número: "))
primos = []

for i in range(2, numero + 1):  # começa do 2
    eh_primo = True

    for j in range(2, i):
        if i % j == 0:
            eh_primo = False
            break

    if eh_primo:
        primos.append(i)

print(primos)

# %% [markdown]
# 6) Escreva um programa que peça uma data informando o dia, mês e ano e determine se ela é válida para uma análise

# %%
day = int(input("Digite o dia: "))
month = int(input("Digite o mês: "))
year = int(input("Digite o ano: "))

mes_31 = [1,3,5,7,8,10,12]
mes_30 = [4,6,9,11]

if month < 1 or month > 12:
    print("Mês inválido")

else:
    if month == 2:
        if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
            limite = 29
        else:
            limite = 28

    elif month in mes_30:
        limite = 30

    else:
        limite = 31

    if day > 0 and day <= limite:
        print("Válido")
    else:
        print("Dia inválido")
    print(day)
    print(month)
    print(year)

# %% [markdown]
# 7) Para um estudo envolvendo o nível de multiplicação de bactérias em uma colônia, foi coletado o número de bactérias por dia (em milhares) e pode ser observado a seguir: [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]. Tendo esses valores, faça um código que gere uma lista contendo o percentual de crescimento de bactérias por dia, comparando o número de bactérias em cada dia com o número de bactérias do dia anterior. Dica: para calcular o percentual de crescimento usamos a seguinte equação: 100 * (amostra_atual - amostra_passada) / (amostra_passada).

# %%
bacterias = [1.2, 2.1, 3.3, 5.0, 7.8, 11.3, 16.6, 25.1, 37.8, 56.9]
crescimento = []

for i in range(1, len(bacterias)):
    atual = bacterias[i]
    anterior = bacterias[i - 1]

    percentual = 100 * (atual - anterior) / anterior
    crescimento.append(percentual)

print(crescimento)

# %% [markdown]
# 8) Para uma seleção de produtos alimentícios, precisamos separar o conjunto de IDs dados por números inteiros sabendo que os produtos com ID par são doces e os com ID ímpar são amargos. Monte um código que colete 10 IDs. Depois, calcule e mostre a quantidade de produtos doces e amargos.

# %%
contadorD = 0
contadorA = 0
for i in range(0,10):
  ID = int(input("Digite o ID do alimento: "))
  if(ID % 2 == 0):
    contadorD +=1
  else:
    contadorA +=1
print(f"Na lista tem {contadorD} alimentos doces e {contadorA} alimentos amargos")
# Out:
# Digite o ID do alimento: 4
# Digite o ID do alimento: 12
# Digite o ID do alimento: 19
# Digite o ID do alimento: 23
# Digite o ID do alimento: 27
# Digite o ID do alimento: 31
# Digite o ID do alimento: 35
# Digite o ID do alimento: 38
# Digite o ID do alimento: 2
# Digite o ID do alimento: 15
# Na lista tem 4 alimentos docês e 6 alimentos amargos

# %% [markdown]
# 9) Desenvolva um programa que informa a nota de um(a) aluno(a) de acordo com suas respostas. Ele deve pedir a resposta desse(a) aluno(a) para cada questão e é preciso verificar se a resposta foi igual ao gabarito. Cada questão vale um ponto e existem as alternativas A, B, C ou D.

# %%
gabarito = ["D","A","C","B","A","D","C","C","A","B"]
pontos = 0
for i in gabarito:
  resposta = input("Digite a resposta da questao: (A,B,C,D)").upper()
  if(resposta == i):
    pontos +=1

print(f"Voce tirou {pontos} na prova")
# Out:
# Digite a resposta da questao: (A,B,C,D)C
# Digite a resposta da questao: (A,B,C,D)A
# Digite a resposta da questao: (A,B,C,D)D
# Digite a resposta da questao: (A,B,C,D)B
# Digite a resposta da questao: (A,B,C,D)B
# Digite a resposta da questao: (A,B,C,D)D
# Digite a resposta da questao: (A,B,C,D)A
# Digite a resposta da questao: (A,B,C,D)C
# Digite a resposta da questao: (A,B,C,D)C
# Digite a resposta da questao: (A,B,C,D)B
# Voce tirou 5 na prova

# %% [markdown]
# 10) Um instituto de meteorologia deseja fazer um estudo de temperatura média de cada mês do ano. Para isso, você precisa fazer um código que colete e armazene essas temperaturas médias em uma lista. Depois, calcule a média anual das temperaturas e mostre todas as temperaturas acima da média anual e em que mês elas ocorreram, mostrando os meses por extenso (Janeiro, Fevereiro, etc.).

# %%
lista = []
listaMes = ["janeiro","fevereiro","março","abril","maio","junho","julho","agosto","setembro","outubro","novembro","dezembro"]
for i in range(0,12):
  temperatura = float(input("Digite a temperatura: "))
  lista.append(temperatura)
mediaAnual = (sum(lista) / 12)
for i in range(0,12):
  if(lista[i] > mediaAnual):
    print(f"A temperatura de {listaMes[i]} ({lista[i]}°C) está acima da média")

# %% [markdown]
# 11) Uma empresa de e-commerce está interessada em analisar as vendas dos seus produtos. Os dados das vendas foram armazenados em um dicionário:
#
# {'Produto A': 300, 'Produto B': 80, 'Produto C': 60,
#  'Produto D': 200, 'Produto E': 250, 'Produto F': 30}
# Escreva um código que calcule o total de vendas e o produto mais vendido.

# %%
dicionario = {
    "Produto A": 300,
    "Produto B": 80,
    "Produto C": 60,
    "Produto D": 200,
    "Produto E": 250,
    "Produto F": 30
}

total = 0
maior_valor = 0
maior_produto = ""

for produto, valor in dicionario.items():
    total += valor

    if valor > maior_valor:
        maior_valor = valor
        maior_produto = produto

print(f"Total de vendas: {total}")
print(f"Produto mais vendido: {maior_produto} ({maior_valor})")
# Out:
# O produto mais caro é 0
# O total de vendas é :920

# %% [markdown]
# 12) Uma pesquisa de mercado foi feita para decidir qual design de marca infantil mais agrada as crianças. A pesquisa foi feita e o votos computados podem ser observados abaixo:
#
# '''
# Tabela de votos da marca
# Design 1 - 1334 votos
# Design 2 - 982 votos
# Design 3 - 1751 votos
# Design 4 - 210 votos
# Design 5 - 1811 votos
#
# Adapte os dados fornecidos para uma estrutura de dicionário. A partir dele, informe o design vencedor e a porcentagem de votos recebidos.

# %%
maior_valor = 0
maior_Design = ""
valor_Total = 0
dicionario = {
    "Design 1" : 1334,
    "Design 2" : 982,
    "Design 3" : 1751,
    "Design 4" : 210,
    "Design 5" : 1811,
}

for Design,valor in dicionario.items():
  valor_Total += valor
  if(valor > maior_valor):
    maior_valor = valor
    maior_Design = Design
porcentagem  = ((maior_valor / valor_Total) *100)


print(f"O Design com mais votos foi {maior_Design} com {maior_valor} votos e a sua porcentagem foi de {porcentagem:.2f}%")
# Out:
# O Design com mais votos foi Design 5 com 1811 votos e a sua porcentagem foi de 29.75%
